# %%
# !unzip /content/sixc.zip -d /content/data
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/data/sixc/datasets/labels/train/knife-518_jpg.rf.73046d730f26b981255cfe87cae6ecc8.txt
#   inflating: /content/data/__MACOSX/sixc/datasets/labels/train/._knife-518_jpg.rf.73046d730f26b981255cfe87cae6ecc8.txt
#   inflating: /content/data/sixc/datasets/labels/train/armas-2-_jpg.rf.5b0fc4bca7b181e2719ea71b1fc84615.txt
#   inflating: /content/data/__MACOSX/sixc/datasets/labels/train/._armas-2-_jpg.rf.5b0fc4bca7b181e2719ea71b1fc84615.txt
#   inflating: /content/data/sixc/datasets/labels/train/armas-343-_jpg.rf.5f5e9659aa19a6068354569cdd97cdc6.txt
#   inflating: /content/data/__MACOSX/sixc/datasets/labels/train/._armas-343-_jpg.rf.5f5e9659aa19a6068354569cdd97cdc6.txt
#   inflating: /content/data/sixc/datasets/labels/train/fall_227_jpg.rf.b22b793112da8c1cebf0825ddb023497.txt
#   inflating: /content/data/__MACOSX/sixc/datasets/labels/train/._fall_227_jpg.rf.b22b793112da8c1cebf0825ddb023497.txt
# ...

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("yolo26n.pt")

# %%
# !yolo task=detect mode=train model=/content/yolo26n.pt data=/content/data/sixc/data2.yaml epochs=100 imgsz=640 plots=True
# Out:
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA H100 80GB HBM3, 81079MiB)
# ...

# %%
model2 = YOLO("yolo26s.pt")

# %%
# !yolo task=detect mode=train model=/content/yolo26s.pt data=/content/data/sixc/data2.yaml  epochs=100 imgsz=640 plots=True
# Out:
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA H100 80GB HBM3, 81079MiB)
# ...

# %%
model3 = YOLO("yolo26m.pt")

# %%
# !yolo task=detect mode=train model=/content/yolo26m.pt data=/content/data/sixc/data2.yaml epochs=100 imgsz=640 plots=True
# Out:
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA H100 80GB HBM3, 81079MiB)
# ...

# %%
model4 = YOLO("yolo26l.pt")

# %%
# !yolo task=detect mode=train model=/content/yolo26l.pt data=/content/data/sixc/data2.yaml epochs=100 imgsz=640 plots=True
# Out:
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA H100 80GB HBM3, 81079MiB)
# ...
