# %%
# !unzip datasets_nodup.zip  -d /content/data
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/data/datasets_nodup/labels/train/V_7_F30_jpg.rf.c4653f621138b13e17bdeca22d223315.txt
#   inflating: /content/data/__MACOSX/datasets_nodup/labels/train/._V_7_F30_jpg.rf.c4653f621138b13e17bdeca22d223315.txt
#   inflating: /content/data/datasets_nodup/labels/train/heavy_weapon-578-_jpg.rf.22b30d27ba3ff84e98729a41d2b9dcb9.txt
#   inflating: /content/data/__MACOSX/datasets_nodup/labels/train/._heavy_weapon-578-_jpg.rf.22b30d27ba3ff84e98729a41d2b9dcb9.txt
#   inflating: /content/data/datasets_nodup/labels/train/V_205_F126_jpg.rf.ede4bb8168e4442add33c5559a602e2f.txt
#   inflating: /content/data/__MACOSX/datasets_nodup/labels/train/._V_205_F126_jpg.rf.ede4bb8168e4442add33c5559a602e2f.txt
#   inflating: /content/data/datasets_nodup/labels/train/armas-338-_jpg.rf.1f654a82c7b295ca52a8a323d1907eae.txt
# ...

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("yolo26n.pt")

# %%
model = YOLO("yolo26s.pt")

# %%
# !yolo task=detect mode=train model=/content/yolo26n.pt data=/content/data/datasets_nodup/data2.yaml epochs=100 imgsz=640 plots=True
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# ...

# %%
# !yolo task=detect mode=train model=/content/yolo26s.pt data=/content/data/datasets_nodup/data2.yaml epochs=100 imgsz=640 plots=True
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# ...

# %%
model3 = YOLO("yolo26m.pt")

# %%
# !yolo task=detect mode=train model=/content/yolo26m.pt data=/content/data/datasets_nodup/data2.yaml epochs=100 imgsz=640 plots=True
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# ...

# %%
model4 = YOLO("yolo26l.pt")

# %%
# !yolo task=detect mode=train model=/content/yolo26l.pt data=/content/data/datasets_nodup/data2.yaml epochs=100 imgsz=640 plots=True
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# ...

# %%
model5 = YOLO("yolo26x.pt")

# %%
# !yolo task=detect mode=train model=/content/yolo26x.pt data=/content/data/datasets_nodup/data2.yaml epochs=100 imgsz=640 plots=True
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# ...

# %%
# !unzip datasets_weapon______1.zip -d /content/data_w
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/data_w/datasets_weapon______1/images/train/knife-519_jpg.rf.9ea7528e06524d054dc3480e43ed3c48.jpg
#   inflating: /content/data_w/__MACOSX/datasets_weapon______1/images/train/._knife-519_jpg.rf.9ea7528e06524d054dc3480e43ed3c48.jpg
#   inflating: /content/data_w/datasets_weapon______1/images/train/knife-168_jpg.rf.b5b73fe8162cafd054fe4eaa9446403f.jpg
#   inflating: /content/data_w/__MACOSX/datasets_weapon______1/images/train/._knife-168_jpg.rf.b5b73fe8162cafd054fe4eaa9446403f.jpg
#   inflating: /content/data_w/datasets_weapon______1/images/train/knife-785_jpg.rf.3de672405bccc67400668cf6a739382e.jpg
#   inflating: /content/data_w/__MACOSX/datasets_weapon______1/images/train/._knife-785_jpg.rf.3de672405bccc67400668cf6a739382e.jpg
#   inflating: /content/data_w/datasets_weapon______1/images/train/armas-382-_jpg.rf.94e657681f633753e278defaa5bb250e.jpg
# ...

# %%
# !yolo task=detect mode=train model=/content/yolo26l.pt data=/content/data_w/datasets_weapon______1/dataw.yaml epochs=100 imgsz=640 plots=True
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# ...

# %%
# !unzip datasets_person_______2.zip -d /content/data_p
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/data_p/datasets_person_______2/images/train/fall_351_jpg.rf.29bee5d536ebda95981b86117243331a.jpg
#   inflating: /content/data_p/__MACOSX/datasets_person_______2/images/train/._fall_351_jpg.rf.29bee5d536ebda95981b86117243331a.jpg
#   inflating: /content/data_p/datasets_person_______2/images/train/V_310_F90_jpg.rf.1252b1c96b0ed02b4b874a3423b56711.jpg
#   inflating: /content/data_p/__MACOSX/datasets_person_______2/images/train/._V_310_F90_jpg.rf.1252b1c96b0ed02b4b874a3423b56711.jpg
#   inflating: /content/data_p/datasets_person_______2/images/train/V_375_F90_jpg.rf.d317f01293c722ac703ce9b32e57853c.jpg
#   inflating: /content/data_p/__MACOSX/datasets_person_______2/images/train/._V_375_F90_jpg.rf.d317f01293c722ac703ce9b32e57853c.jpg
#   inflating: /content/data_p/datasets_person_______2/images/train/fall_61_jpg.rf.140d4770b7292d3d35e5f46ef8ce4eb1.jpg
# ...

# %%
# !yolo task=detect mode=train model=/content/yolo26l.pt data=/content/data_p/datasets_person_______2/datap.yaml epochs=100 imgsz=640 plots=True
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# ...

# %%
from ultralytics import RTDETR

# %%
model6 = RTDETR("rtdetr-l.pt")

# %%
results = model6.train(
    data="/content/data/datasets_nodup/data2.yaml",
    epochs=100,
    imgsz=640,
    batch=8,
    amp=False,
    lr0=0.0005
)
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# ...
